# %% [markdown]
# # San Francisco Airport - Clustering

# %%
# in this notebook we will preparing a airplane clustering mdoel

# %%
#import libraries

# %%
#!pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.4/159.4 kB 17.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 69.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 85.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from yellowbrick.cluster import KElbowVisualizer
from scipy.cluster.hierarchy import dendrogram, linkage
from pycaret.clustering import*
import joblib

# %%
#read the data

# %%
df=pd.read_csv("air-traffic-passenger-statistics (2).csv")

# %% [markdown]
# ### EDA

# %%
# see first 5 cells

# %%
df.head()
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507      ATA Airlines                          TZ
# 1           200507      ATA Airlines                          TZ
# 2           200507      ATA Airlines                          TZ
# 3           200507        Air Canada                          AC
# 4           200507        Air Canada                          AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0      ATA Airlines                          TZ       Domestic         US
# 1      ATA Airlines                          TZ       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3        Air Canada                          AC  International     Canada
# 4        Air Canada                          AC  International     Canada
#
#   Activity Type Code Price Category Code    Terminal Boarding Area  \
# ...

# %%
#see data shape

# %%
df.shape
# Out:
# (18885, 12)

# %%
#see information from data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18885 entries, 0 to 18884
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              18885 non-null  int64
#  1   Operating Airline            18885 non-null  object
#  2   Operating Airline IATA Code  18822 non-null  object
#  3   Published Airline            18885 non-null  object
#  4   Published Airline IATA Code  18822 non-null  object
#  5   GEO Summary                  18885 non-null  object
#  6   GEO Region                   18885 non-null  object
#  7   Activity Type Code           18885 non-null  object
#  8   Price Category Code          18885 non-null  object
#  9   Terminal                     18885 non-null  object
#  10  Boarding Area                18885 non-null  object
#  11  Passenger Count              18885 non-null  int64
# dtypes: int64(2), object(10)
# memory usage: 1.7+ MB

# %%
# see statisticcs about data

# %%
df.describe().T.round(2)
# Out:
#                    count       mean       std       min       25%       50%  \
# Activity Period  18885.0  201179.29    385.76  200507.0  200811.0  201204.0
# Passenger Count  18885.0   29876.74  60626.07       1.0    5352.0    9170.0
#
#                       75%       max
# Activity Period  201509.0  201806.0
# Passenger Count   20718.0  659837.0

# %%
# see the corelaitons belong to data

# %%
df.corr()
# Out:
#                  Activity Period  Passenger Count
# Activity Period         1.000000         0.050677
# Passenger Count         0.050677         1.000000

# %%
# see datas columns names

# %%
df.columns
# Out:
# Index(['Activity Period', 'Operating Airline', 'Operating Airline IATA Code',
#        'Published Airline', 'Published Airline IATA Code', 'GEO Summary',
#        'GEO Region', 'Activity Type Code', 'Price Category Code', 'Terminal',
#        'Boarding Area', 'Passenger Count'],
#       dtype='object')

# %%
# is data have missing values? see

# %%
df.isnull().sum()
# Out:
# Activity Period                 0
# Operating Airline               0
# Operating Airline IATA Code    63
# Published Airline               0
# Published Airline IATA Code    63
# GEO Summary                     0
# GEO Region                      0
# Activity Type Code              0
# Price Category Code             0
# Terminal                        0
# Boarding Area                   0
# Passenger Count                 0
# dtype: int64

# %% [markdown]
# ### Handdle missing values

# %%
#drop mising values

# %%
df.dropna(axis=0, inplace=True)

# %%
#chek

# %%
df.isnull().sum()
# Out:
# Activity Period                0
# Operating Airline              0
# Operating Airline IATA Code    0
# Published Airline              0
# Published Airline IATA Code    0
# GEO Summary                    0
# GEO Region                     0
# Activity Type Code             0
# Price Category Code            0
# Terminal                       0
# Boarding Area                  0
# Passenger Count                0
# dtype: int64

# %% [markdown]
# ### preprocesing

# %%
#turn object columns into numeric

# %%
df_dummies = pd.get_dummies(df,drop_first=True)

# %% [markdown]
# ### modeling

# %%
#setup df

# %%
setup(df)
# Out:
# <style type="text/css">
# #T_740e6_row6_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_740e6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_740e6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_740e6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_740e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_740e6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_740e6_row0_col1" class="data row0 col1" >357</td>
#     </tr>
#     <tr>
#       <th id="T_740e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_740e6_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_740e6_row1_col1" class="data row1 col1" >(18822, 12)</td>
#     </tr>
#     <tr>
# ...

# %%
#create model

# %%
kmeans = create_model('kmeans', 4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_96d0b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96d0b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_96d0b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_96d0b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_96d0b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_96d0b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_96d0b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96d0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96d0b_row0_col0" class="data row0 col0" >0.7854</td>
#       <td id="T_96d0b_row0_col1" class="data row0 col1" >93879.6652</td>
# ...

# %%
#create model drawing

# %%
plot_model(kmeans)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#draw elbow mthode to find optimum cluster count

# %%
plot_model(kmeans, plot='elbow')

# %%
#save model

# %%
joblib.dump(kmeans, "san_francisco_clustering.joblib")
# Out:
# ['san_francisco_clustering.joblib']
